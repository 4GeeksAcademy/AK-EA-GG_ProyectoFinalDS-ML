# %% [markdown]
# # 🧠 Proyecto Final de Machine Learning
#
# ## 👥 Grupos de Trabajo
# - Equipos de **3 personas**.
# - El trabajo debe ser **colaborativo**.
#
# ---
#
# ## 🧩 Fases del Proyecto
#
# ### 1. Definición del Problema
# - Definir un problema real y transformarlo en uno de Machine Learning.
# - El dataset debe cumplir:
#   - **60.000 filas (instancias)** mínimo.
#   - **20 variables predictoras** (al menos 1 categórica).
# - *Se pueden aceptar excepciones justificadas.*
#
# ---
#
# ### 2. Obtención y Carga de Datos
# - Obtener datos desde:
#   - Web scraping.
#   - Base de datos pública con SQL.
#   - API pública.
# - Guardar los datos en formato **CSV** y cargarlos con **Pandas**.
# - *Otras fuentes pueden considerarse según el caso práctico.*
#
# ---
#
# ### 3. Almacenamiento de la Información
# - Usar una **base de datos** adecuada según los datos.
# - Realizar consultas útiles en Python (`SELECT`, `JOIN`, `INSERT`, etc.).
# - Ventajas sobre el CSV:
#   - Mejor persistencia.
#   - Seguridad.
#   - Consultas estructuradas.
#
# ---
#
# ### 4. Análisis Descriptivo
# - Calcular medidas estadísticas:
#   - Media, moda, desviación, distribución, etc.
# - Analizar la distribución de cada variable.
# - Realizar **contrastes de hipótesis** si aplica.
#
# ---
#
# ### 5. Análisis Exploratorio (EDA)
# - Eliminar variables irrelevantes.
# - Seleccionar las más informativas.
# - Separar el dataset en **train** y **test**.
#
# ---
#
# ### 6. Construcción y Optimización del Modelo
# - Seleccionar el mejor modelo tras evaluar varios.
# - Aplicar **optimización de hiperparámetros**.
#
# ---
#
# ### 7. Despliegue del Modelo
# - Crear una **aplicación web** con el modelo (Flask, Streamlit, etc.).
# - Desplegar en **Heroku, Render**, u otra plataforma en la nube.
# - La app debe ser funcional y fácil de usar para el usuario final.
#
# ---
#
# ## 🎤 Presentación del Proyecto
#
# ### ⏱ Duración: 5 minutos por grupo
#
# ### 🔑 Puntos clave a presentar:
# - ¿Cuál es el **problema de negocio** que se quiere resolver?
# - ¿Cómo se **recopilaron los datos**?
# - Principales **patrones y hallazgos** encontrados.
# - **Algoritmo** y **métrica de evaluación** utilizados.
# - Demostración de la **aplicación web** y posibles mejoras futuras.
#
# > ⚠️ **Evitar explicar el código en detalle**.
# > Presenta como si hablaras con inversores o partes interesadas no técnicas.
